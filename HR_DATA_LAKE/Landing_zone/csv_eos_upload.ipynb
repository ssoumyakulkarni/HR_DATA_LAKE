# %%
import mysql.connector
mydb = mysql.connector.connect(host='arohamysqlrds.cvc8b2isrkrv.us-west-2.rds.amazonaws.com', user='datalake', passwd='datalake', database='eos_live')
print(mydb.is_connected())
# Out:
# True

# %%
print(mydb.is_connected())
mycursor = mydb.cursor(dictionary=True)
mycursor.execute('select AppUser_Id,Emp_Code,APP_User_First_Name,APP_User_Last_Name,APP_User_Middle_Name,Gender,Date_Of_Birth,Email_Id,LoginID,Phone_Number from AppUsers')
result = mycursor.fetchall()
print(result)
# Out:
# True
# ...

# %%
len(result)
print(result[0].values())
# Out:
# dict_values([1, 'A1001', 'Rajesh', 'Shanmugam', 'Kumar', 'M', datetime.date(1971, 9, 22), 'rajesh@aroha.co.in', 'rajesh@aroha.co.in', '9845078308'])

# %%
import csv
with open('EOS.csv', 'w',) as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(result[0].keys())
    for r in result:
        writer.writerow(r.values())

# %%
import boto3
from botocore.exceptions import NoCredentialsError

ACCESS_KEY = 'AKIATRFCG35IBJUBVMMG'
SECRET_KEY = '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'


def upload_to_aws(local_file, bucket, s3_file):
    s3 = boto3.client('s3', aws_access_key_id=ACCESS_KEY,
                      aws_secret_access_key=SECRET_KEY,
                     region_name="Asia Pacific (Mumbai)",
                      endpoint_url="https://s3.ap-south-1.amazonaws.com")
    print("inside")

    try:
        s3.upload_file(local_file, bucket, s3_file)
        print("Upload Successful")
        return True
    except FileNotFoundError:
        print("The file was not found")
        return False
    except NoCredentialsError:
        print("Credentials not available")
        return False


uploaded = upload_to_aws('EOS.csv', 'hrdatalake', 'landing_zone/{}'.format('EOS.csv'))
# Out:
# inside
# Upload Successful
