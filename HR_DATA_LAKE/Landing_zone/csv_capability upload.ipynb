# %%
import mysql.connector
mydb = mysql.connector.connect(host='arohamysqlrds.cvc8b2isrkrv.us-west-2.rds.amazonaws.com', user='datalake', passwd='datalake', database='capability')
print(mydb.is_connected())
# Out:
# True

# %%
print(mydb.is_connected())
mycursor = mydb.cursor(dictionary=True)
capability_sql= "select COUNT(DISTINCT ua.question_id) as Total_Marks, ua.test_id,tu.email,tu.phone, tt.correct_answers as Correct_Answers, tu.first_name as First_Name, tu.last_name as Last_Name,ts.name as Skill_Level, DATE_FORMAT(ua.Inserted_Date_Time, '%d/%m/%Y') as Test_Date, tqt.name as Topic_Name from tbl_users_answers as ua JOIN tbl_tests as tt ON ua.user_id = tt.user_id and ua.test_id = tt.test_id Join tbl_users as tu on ua.user_id = tu.id  JOIN tbl_questiontopic as tqt on tqt.id = tt.topic_id  JOIN tbl_skills as ts on ts.skills_id = tt.skill_level_id join tbl_topic_skilllevel as tts on tts.topic_id=tts.topic_id GROUP BY tt.id"

mycursor.execute(capability_sql)
result = mycursor.fetchall()
print(result)
# Out:
# True
# ...

# %%
len(result)
print(result[0].values())
# Out:
# dict_values([19, 'MS-SQL-Simple-2', '123pallavibiradar@gmail.com', 7795740325, 10, 'pallavi', 'b', 'Beginner', '24/08/2019', 'MS-SQL'])

# %%
import csv
with open('capability.csv', 'w',) as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(result[0].keys())
    for r in result:
        writer.writerow(r.values())

# %%
import boto3
from botocore.exceptions import NoCredentialsError

ACCESS_KEY = 'AKIATRFCG35IBJUBVMMG'
SECRET_KEY = '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'


def upload_to_aws(local_file, bucket, s3_file):
    s3 = boto3.client('s3', aws_access_key_id=ACCESS_KEY,
                      aws_secret_access_key=SECRET_KEY,
                     region_name="Asia Pacific (Mumbai)",
                      endpoint_url="https://s3.ap-south-1.amazonaws.com")
    print("inside")

    try:
        s3.upload_file(local_file, bucket, s3_file)
        print("Upload Successful")
        return True
    except FileNotFoundError:
        print("The file was not found")
        return False
    except NoCredentialsError:
        print("Credentials not available")
        return False


uploaded = upload_to_aws('capability.csv', 'hrdatalake', 'landing_zone/{}'.format('capability.csv'))
# Out:
# inside
# Upload Successful
